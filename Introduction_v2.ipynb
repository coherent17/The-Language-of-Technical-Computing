# %% [markdown]
# <br />
# <br />
# <br />
#
#
# <center><h1>Python Tutorial</h1></center>
#
# <br />
# <br />
# <center>Time: R78 (15:30~16:20 and 16:30~17:20)</center>
# <br />
#
# <center><h4>Teacher: Chung-Hao Tien (田仲豪)</h4></center>
# <center><h4>TA: Chih-Chieh Yang (楊智捷) $^1$ Chia-Ling Tu (涂佳伶) $^2$ Ming-Hsuan Wu (吳銘軒) $^3$</h4></center>
#
# <center><h4>E-mail: yangzhijie.eo06@g2.nctu.edu.tw $^1$ jialing.dop09g@nctu.edu.tw $^2$ mhwu.dop09g@nctu.edu.tw $^3$</h4></center>
#
# <center><h4>Date: 03/04/2021</h4></center>

# %% [markdown]
# <h2>Schedule</h2>
#
# * Week2:
#     * Environment setup: `Anaconda`, `Jupyter notebook`, and `Google Colab`
#     * Print(), variables
#
# * Week2/3:
#     * Datatypes 1: **str** *`"Hello world"`*, **int** *`87`*, **float** *`3.14`*, **complex** *`0.2+5j`*, **bool** *`True`*, *`False`*
#
#     * Datatypes 2: **list** *`[1, 2, 3]`*, **tuple** *`(1, 2, 3)`*, **dict** *`{1:'1', 2:'2'}`*, **set** *`{1, 2, 3}`*
#
# * Week3:
#     * Conditional: if and elif
#     * While and for loops
#     * Functions (函數), ~~Classes(類別)~~

# %% [markdown]
# * Week4
#     * Modules 1: Numpy *(array, tensor)*
# * Week5
#     * Modules 2: Matplotlib
# * Week6
#     * Modules 3: Scipy
# * Week7
#     * Geometric transformation in 2D plane
# * Week8: Midterm week
#
# * Week9~Week15: **Mr.Tian in class**

# %% [markdown]
#  <img align="left" width="150" height='150' src="data:image/png;base64,..." />
#
# <h2>IDE </h2>
#
#
# **Jupyter notebook**: interactive data science environment
#
#
# <h2>Grading system</h2>
#
# * **4** (easy) exams (about **50%** in total)
#     * **Errors** would get **0%** in total
#     * Filename, and signature must follow the template: **Quiz1_studentID_chineseName.ipynb**
#     * **Late** assignment would get **0%** in total
#     * **Plagiarism**(抄襲) is strictly prohibited, that is **0%**
#     * Remember to save your outputs and add comments beside your source code
#
# * Final project (about 50% in total)
# * Mr.Tian would decide how to adjust final grade
#
# PS: Will keep simple bcs **2 hours $\rightarrow$  only 1 credit  (ఠ్ఠ ˓̭ ఠ్ఠ)**

# %% [markdown]
# <h2>Top 10 Most Popular Programming Languages</h2>
#
# <center><img height='1000' width='1200' src="data:image/png;base64,..." /"></center>
#
#
#
# [(From VentureBeat)](https://venturebeat.com/2020/12/02/github-python-and-typescript-gain-popularity-among-programming-languages/)

# %% [markdown]
# <h2>Why Python ?</h2>
#
#
# <!-- ![From Github](rank.png) -->
#
#
#
# <img align="right" width="800" height="500" src="data:image/png;base64,...">
#
#
# ### Pros
#
# * Easy-to-learn <sub> $\rightarrow$ [Learn Python in 4 hours!](https://www.youtube.com/watch?v=rfscVS0vtbw)</sub>
#
#
# * Plenty of online resources
#   <sub> $\rightarrow$ [Github](https://github.com/), [StackOverflow](https://stackoverflow.com/)</sub>
#
#
# * Popular in AI, deep learning
#   <sub>[Tensorflow](https://www.tensorflow.org/?hl=zh-tw), [Pytorch](https://pytorch.org/)</sub>

# %% [markdown]
# <h2>Why Python ?</h2>
#
#
# <!-- ![From Github](rank.png) -->
#
#
#
# <img align="right" width="800" height="500" src="data:image/png;base64,...">
#
#
# ### Cons
#
# * Interpreted language <sub>$\rightarrow$ a little bit slower</sub>
#
# * High Memory Consumption

# %% [markdown]
# <h2>Install Anaconda</h2>
#
# <img class="left" width="900" height="800" src="data:image/png;base64,...">

# %% [markdown]
# <h2>Install Anaconda</h2>
#
# <img class="left" width="900" height="800" src="data:image/png;base64,...">

# %% [markdown]
# <h2>Install Anaconda</h2>
#
# <img class="left" width="500" height="800" src="data:image/png;base64,...">

# %% [markdown]
# <h2>Install Anaconda</h2>
#
# <img class="left" width="900" height="800" src="data:image/png;base64,...">

# %% [markdown]
# <h2>Install Anaconda</h2>
#
# <img class="left" width="900" height="800" src="data:image/png;base64,...">

# %% [markdown]
# <h2>Install Anaconda</h2>
#
# <img class="left" width="900" height="800" src="data:image/png;base64,...">

# %% [markdown]
# <h2>Install Anaconda</h2>
#
# <img class="left" width="900" height="800" src="data:image/png;base64,...">

# %% [markdown]
# <h2>Install Anaconda</h2>
#
# **!!選項一不要打勾!!**
#
# <img align="left" width="900" height="800" src="data:image/png;base64,...">

# %% [markdown]
# <h2>Launch Anaconda</h2>
#
# <img class="left" width="900" height="800" src="data:image/png;base64,...">

# %% [markdown]
# <h2>Launch JupyterNotebook</h2>
#
# <img align="left" width="1200" src="data:image/png;base64,...">

# %% [markdown]
# <h2>Launch JupyterNotebook</h2>
#
# <img align="right" width="750" height="550" src="data:image/png;base64,...">
#
#
# * At first, you need to install `Jupyter Notebook`
#
# * After that, you can launch directly from Powershell
#
#     $\rightarrow$`cd/d D:/codes/...your code dir.../`
#
#     $\rightarrow$`jupyter notebook`

# %% [markdown]
# <h2>Launch JupyterNotebook</h2>
#
# <img align="right" width="1000" src="data:image/png;base64,...">
#
# * Copy your jupyter link to browser

# %% [markdown]
# <img align="left" height="256" width="256" src="data:image/png;base64,...">
#
# <h2>Google colab - Another Online JupyterNotebook</h2>
#
# Link: https://colab.research.google.com/
#
# <br />
#
# >_Colab is a hosted Jupyter notebook service that requires no setup to use, while providing free access to computing resources including GPUs._
#
# * Free server
#
# * Free CPU, GPU(nvidia) and TPU
#
# * Can mount to google drive $\leftarrow$unlimited storage in G-Suite account (2022 not anymore 🤕)
